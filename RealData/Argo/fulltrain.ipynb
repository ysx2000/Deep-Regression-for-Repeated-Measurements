# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
import numpy as np
import matplotlib.pyplot as plt
import math
import matplotlib
import matplotlib.pyplot as plt
import numpy as np 
import torch             # torch基础库
import torch.nn as nn    # torch神经网络库
import torch.nn.functional as F    # torch神经网络库 
import pandas as pd
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset
from PIL import Image 
import imageio 
from early_stopping import EarlyStopping
import os, gc
import random 
import pynvml
import multiprocessing
import itertools
import subprocess
import gc
from functools import partial
from pandarallel import pandarallel
import rpy2.robjects as robjects
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cartopy.feature as cfe
import cartopy.crs as ccrs 
import xarray as xr
import imageio
import numpy as np
import pandas as pd
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import matplotlib.colors as mcolors
import matplotlib as mpl
from torch.backends import cudnn
cudnn.benchmark = False
cudnn.deterministic = True
def worker_init_fn(worker_id):
    random.seed(123 + worker_id)

def get_gpu_memory(device_id):
    try:
        output = subprocess.check_output(["nvidia-smi", "--id={}".format(device_id), "--query-gpu=memory.used,memory.total", "--format=csv,nounits,noheader"])
        memory_used, memory_total = map(int, output.decode("utf-8").strip().split("\n")[0].split(","))
        return memory_used, memory_total
    except Exception as e:
        print(e)
        return None, None

def get_free_gpu():
    device_ids = list(range(torch.cuda.device_count()))
    memory_usages = []
    for device_id in device_ids:
        memory_used, memory_total = get_gpu_memory(device_id)
        if memory_used is not None and memory_total is not None:
            memory_free = memory_total - memory_used
            memory_usages.append((device_id, memory_free))
        print(memory_total,memory_usages)
    if len(memory_usages) > 0:
        best_device_id = sorted(memory_usages, key=lambda x: x[1])[len(device_ids)-1][0]
        # print(sorted(memory_usages, key=lambda x: x[1]))
        device = torch.device(f"cuda:{best_device_id}")
        return device
    else:
        return None


class Args:
    def __init__(self, batch_size=10, lr =0.001, nepoch = 500, patience = 10, wide = 100, depth = 5, n_train=1, m_train=1) -> None:
        self.batch_size = batch_size 
        self.lr = lr 
        self.nepoch = nepoch 
        self.patience = patience 
        self.wide = wide 
        self.depth = depth 
        self.biaoji = "wide" + str(wide) + "depth" + str(depth) + "n" + str(n_train) + "m" + str(m_train)
        self.n_train = n_train
        self.m_train = m_train


class EarlyStopping():
    def __init__(self, save_path, args, verbose=False, delta=0):
        self.save_path = save_path 
        self.patience = args.patience 
        self.verbose = verbose 
        self.counter = 0 
        self.best_score = None 
        self.early_stop = False 
        self.val_loss_min = np.Inf 
        self.delta = delta 

    def __call__(self, model, train_loss, valid_loss, args, seed):

        score = -valid_loss 

        if self.best_score is None: 
            self.best_score = score 
            self.save_checkpoint(model, train_loss, valid_loss, args, seed) 
        elif score < self.best_score + self.delta: 
            self.counter += 1 
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}') 
            if self.counter >= self.patience: 
                self.early_stop = True 
        else:
            self.best_score = score
            self.save_checkpoint(model, train_loss, valid_loss, args, seed)
            self.counter = 0

    def save_checkpoint(self, model, train_loss, valid_loss, args, seed):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {valid_loss:.6f}).  Saving model ...') 
        torch.save(model, os.path.join(self.save_path, 'best' + str(seed) + args.biaoji +'network.pth') )	
        torch.save(train_loss, os.path.join(self.save_path, 'best'+ str(seed) + args.biaoji +'train_loss.pth')) 
        torch.save(valid_loss, os.path.join(self.save_path, 'best'+ str(seed) + args.biaoji +'valid_loss.pth')) 

        self.val_loss_min = valid_loss
    
class Dataset_repeatedmeasurement(Dataset): 
    def __init__(self, x, y) -> None: 
        super().__init__()
        self.x = x 
        self.y = y 

    def __len__(self) -> int: 
        return len(self.x) 
    
    def __getitem__(self, index): 
        return {
            "x" : self.x[index], 
            "y" : self.y[index]
        }


class happynet(nn.Module):
    def __init__(self, n_feature, n_hidden, n_output, n_layer): 
        super().__init__()
        if n_layer == 3: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_output), 
            )
        elif n_layer == 2: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_output), 
            )    
        elif n_layer == 4: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_output), 
            )
        elif n_layer == 5: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        elif n_layer == 6: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        elif n_layer == 7: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        elif n_layer == 8: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        elif n_layer == 9: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        elif n_layer == 10: 
            self.net = nn.Sequential(
                nn.Linear(n_feature, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),  
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden), 
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_hidden),
                nn.ReLU(),
                nn.Linear(n_hidden, n_output),
            )
        else: 
            print("Error! the depth is not in 3-10")

    def forward(self, x):
        k = self.net(x)
        return k

# %%
def GPUstrain2(x, y, x_valid, y_valid, args,seed,nocuda): 

    x_dim = 2

    if nocuda == 0:
        device = torch.device("cuda:0")
    if nocuda == 1:
        device = torch.device("cuda:1")
    if nocuda == 100:
        device = get_free_gpu()
    if nocuda == 9:
        device = torch.device("cuda")   
    if nocuda == -1:
        device = torch.device("cpu")

    net = happynet(n_feature=x_dim, n_hidden=args.wide, n_output=1, n_layer=args.depth).to(device)
    nepoch = args.nepoch
    
    optimizer=torch.optim.Adam(net.parameters(), lr=args.lr, betas=(0.90, 0.999), eps=1e-8, weight_decay=0., amsgrad=False,) 
    loss_func=nn.MSELoss() 
    train_epochs_loss = [] 
    valid_epochs_loss = [] 
    x = x.reshape(-1,x_dim)
    y = y.reshape(-1)

    g = torch.Generator()
    g.manual_seed(20000331)
    train_dataset = Dataset_repeatedmeasurement(x,y)
    train_dataloader = DataLoader(dataset=train_dataset, batch_size=args.batch_size, 
                                  shuffle=True, 
                                  worker_init_fn=worker_init_fn, 
                                  generator=g)

    x=torch.from_numpy(x).float() 
    y=torch.from_numpy(y).float() 
    x_valid=torch.from_numpy(x_valid).float().to(device) 
    y_valid=torch.from_numpy(y_valid).float().to(device) 

    xp = x.to(device)
    yp = y.to(device)

    save_path = "./resultsv" 
    early_stopping = EarlyStopping(save_path,args=args)

    for epoch in range(nepoch): 
        net.train()
        train_epoch_loss = []

        # =========================train=========================
        for idx, traindata in enumerate(train_dataloader):

            x_train = traindata["x"]
            y_train = traindata["y"]

            x_train=torch.Tensor(x_train).float().view(-1,1,x_dim).to(device) 
            y_train=torch.Tensor(y_train).float().to(device) 

            outputs=net(x_train) 

            loss=loss_func(outputs.view(-1),y_train.view(-1).float())

            optimizer.zero_grad() 

            loss.backward() 
            optimizer.step()
            
            
            train_epoch_loss.append(loss.item())

        del outputs, loss

        train_epochs_loss.append(np.average(train_epoch_loss))

        # =========================valid=========================
        with torch.no_grad():
            net.eval() 

            valid_predict=net(x_valid.view(-1,1,x_dim))
            valid_y_pre=valid_predict.view(-1).detach()
            valid_y_pre=torch.Tensor(valid_y_pre).float()
            loss_valid=loss_func(valid_y_pre, y_valid.view(-1).float())
            valid_epochs_loss.append(loss_valid.item())

            p_predict=net(xp.view(-1,1,x_dim))
            p_y_pre=p_predict.view(-1).detach()
            p_y_pre=torch.Tensor(p_y_pre).float()
            loss_p=loss_func(p_y_pre, yp.view(-1).float())

        print("epoch = {}, training loss = {}, validation loss = {}".format(epoch, loss_p, loss_valid))#, error_test
        if epoch > 10:
            early_stopping(net, np.average(train_epoch_loss), loss_valid, args,seed)
            if early_stopping.early_stop: 
                print("Early stopping")
                break 

        del valid_predict, valid_y_pre, loss_valid
    gc.collect()

    return net, train_epochs_loss, valid_epochs_loss

# %%
torch.manual_seed(321) 
np.random.seed(321) 
random.seed(321) 
torch.cuda.manual_seed_all(321) 
zong = 180
randind = list(range(zong))
random.shuffle(randind)
train_ind = [randind[i] for i in range(0, math.ceil(zong * 0.8 ))]
valid_ind = [randind[i] for i in range(math.ceil(zong * 0.8), math.ceil(zong))]


traindata = np.empty(shape=(0,3))
validdata = np.empty(shape=(0,3))

for ind in train_ind: 
    year = 2003 + ind//9 
    numon = ind % 9 + 1 
    robjects.r['load']("./data/year" + str(year) + "day" + str(numon) + ".Rdata") 
    traindata = np.append(traindata, np.array(robjects.r['data2sal']),axis=0) 

for ind in valid_ind: 
    year = 2003 + ind//9 
    numon = ind % 9 + 1 
    robjects.r['load']("./data/year" + str(year) + "day" + str(numon) + ".Rdata") 
    validdata = np.append(validdata, np.array(robjects.r['data2sal']),axis=0) 

traindata = traindata[np.isfinite(traindata[:,1]),]
validdata = validdata[np.isfinite(validdata[:,1]),]

for i in range(len(traindata[:,0])):
    if traindata[i,0] < 0:
        traindata[i,0] = traindata[i,0] + 360
    traindata[i,0] = (traindata[i,0] - 100)/180
    traindata[i,1] = (traindata[i,1] + 60)/120

for i in range(len(validdata[:,0])):
    if validdata[i,0] < 0:
        validdata[i,0] = validdata[i,0] + 360
    validdata[i,0] = (validdata[i,0] - 100)/180
    validdata[i,1] = (validdata[i,1] + 60)/120

x_train = traindata[:,:2].reshape(-1,2)
y_train = traindata[:,2].reshape(-1)
x_valid = validdata[:,:2].reshape(-1,2)
y_valid = validdata[:,2].reshape(-1)
    
nm = len(x_train)
print(nm)

batch_size= 64
lr = 0.0005

nocuda = 9
torch.manual_seed(54321) 
np.random.seed(54321) 
random.seed(54321) 
torch.cuda.manual_seed_all(54321) 
args = Args(lr=lr, wide=50, depth = 2, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)

a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net0 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c0 = np.r_[a,b,0]

args = Args(lr=lr, wide=100, depth = 3, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)
a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net1 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c1 = np.r_[a,b,1]


args = Args(lr=lr, wide=200, depth = 4, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)
a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net2 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c2 = np.r_[a,b,2]

args = Args(lr=lr, wide=400, depth = 5, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)
a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net3 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c3 = np.r_[a,b,3]

args = Args(lr=lr, wide=600, depth = 6, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)
a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net4 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c4 = np.r_[a,b,4]

args = Args(lr=lr, wide=800, depth = 6, batch_size= batch_size)
GPUstrain2(x=x_train,y=y_train,x_valid = x_valid,y_valid=y_valid, args=args,seed = 54321, nocuda = nocuda)
a = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'train_loss.pth')
b = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'valid_loss.pth')
net5 = torch.load('./resultsv/best'+ str(54321) + args.biaoji +'network.pth')
a = np.expand_dims(a , 0)
b = np.expand_dims(b.cpu(), 0)
c5 = np.r_[a,b,5]

p = np.r_[np.expand_dims(c0, 0),np.expand_dims(c1, 0),np.expand_dims(c2, 0),np.expand_dims(c3, 0),np.expand_dims(c4, 0),np.expand_dims(c5, 0)]
ind = np.argmin(p[:,1])
torch.save( eval("net"+str(ind)) , os.path.join("./bestnet/", 'bestsalnet.pth'))

            
from global_land_mask import globe
net = torch.load("./bestnet/bestsalnet.pth").cuda()
lat = np.arange(-59.5, 60, 1)
long = np.hstack((np.arange(-179.5, -80, 1), np.arange(100.5, 180, 1)))

grid_lat, grid_long = np.meshgrid(lat,long)
grid_lat = grid_lat.reshape(-1)
grid_long = grid_long.reshape(-1)
panding = (globe.is_land(grid_lat,grid_long) == False)
for i in range(len(grid_long)):
    if grid_long[i] > -100 and grid_long[i] <0 and grid_lat[i] > 45: 
        panding[i] = False

grid_lat = grid_lat[panding]
grid_long = grid_long[panding]
grid_lat1 = grid_lat.copy()
grid_long1 = grid_long.copy()

for i in range(len(grid_long)):
    if grid_long1[i] < 0:
        grid_long1[i] = grid_long1[i] + 360
        grid_long[i] = grid_long[i] + 360
    grid_long1[i] = (grid_long1[i] - 100)/180
    grid_lat1[i] = (grid_lat1[i] + 60)/120
gridt = torch.from_numpy(np.dstack((grid_long1,grid_lat1))).float().cuda()
grid_predict=net(gridt.view(-1,1,2))
grid_y_pre=grid_predict.view(-1).detach()
grid_y_pre=torch.Tensor(grid_y_pre).float()
grid_y = np.array(grid_y_pre.cpu())

plt.figure(dpi=300,figsize=(8,6))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))  
extend=[-80, 100,-60, 60] 

ax.set_extent(extend,crs=ccrs.PlateCarree(central_longitude=180)) 
ax.add_feature(cfe.LAND,edgecolor='black')
ax.set_xticks(np.array([-80,-110,-140,-170,160,130,100]), crs=ccrs.PlateCarree())
ax.set_yticks(np.arange(-60,90,30), crs=ccrs.PlateCarree(central_longitude=180))
lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
    
ax.coastlines() 
ax.set_title("Salinity, 0-50 decibars")
levels = np.arange(33,38, 0.001) 

cmap = "jet"
cmo = plt.cm.get_cmap(cmap)
cs, k = list(), 256/cmo.N
for i in range(cmo.N):
    c = cmo(i)
    for j in range(int(i*k), int((i+1)*k)):
        cs.append(c) 
cs = np.array(cs) 
h = ax.scatter(grid_long-180,grid_lat, s = 8, color = cs[np.uint8(255*(grid_y-31)/6.2)])
sm = plt.cm.ScalarMappable(cmap=cmap) 
sm._A = [] 
cax = plt.gca().inset_axes([1.05, 0.1, 0.03, 0.8])
cb = plt.colorbar(sm,cax=cax) 
cb.set_ticks([0.1613,0.484,0.8065]) 
cb.set_ticklabels([32,34,36])
plt.show()
# Out:
# 24413
# epoch = 0, training loss = 768.1655883789062, validation loss = 766.1121215820312
# epoch = 1, training loss = 176.21231079101562, validation loss = 173.29478454589844
# epoch = 2, training loss = 31.854524612426758, validation loss = 30.60546875
# epoch = 3, training loss = 23.705575942993164, validation loss = 23.0968074798584
# epoch = 4, training loss = 19.651309967041016, validation loss = 19.188190460205078
# epoch = 5, training loss = 15.468174934387207, validation loss = 15.127257347106934
# epoch = 6, training loss = 11.43761157989502, validation loss = 11.199651718139648
# epoch = 7, training loss = 7.874461650848389, validation loss = 7.7205610275268555
# epoch = 8, training loss = 4.994784832000732, validation loss = 4.897741317749023
# epoch = 9, training loss = 2.908535957336426, validation loss = 2.861132860183716
# epoch = 10, training loss = 1.620047926902771, validation loss = 1.5980082750320435
# epoch = 11, training loss = 0.9733690023422241, validation loss = 0.9663280248641968
# epoch = 12, training loss = 0.7179720401763916, validation loss = 0.7183288335800171
# epoch = 13, training loss = 0.6416469812393188, validation loss = 0.6446719765663147
# epoch = 14, training loss = 0.6250918507575989, validation loss = 0.6299804449081421
# epoch = 15, training loss = 0.6219978928565979, validation loss = 0.6274504065513611
# epoch = 16, training loss = 0.6202090382575989, validation loss = 0.6261925101280212
# epoch = 17, training loss = 0.6198405623435974, validation loss = 0.6260148286819458
# epoch = 18, training loss = 0.6160409450531006, validation loss = 0.622520923614502
# epoch = 19, training loss = 0.6126223206520081, validation loss = 0.6193311810493469
# epoch = 20, training loss = 0.6086692214012146, validation loss = 0.6153565049171448
# epoch = 21, training loss = 0.6044514179229736, validation loss = 0.610876739025116
# epoch = 22, training loss = 0.5966706871986389, validation loss = 0.6029866337776184
# epoch = 23, training loss = 0.5874308943748474, validation loss = 0.5940123796463013
# epoch = 24, training loss = 0.5744717717170715, validation loss = 0.5815651416778564
# epoch = 25, training loss = 0.5669927000999451, validation loss = 0.5745046734809875
# epoch = 26, training loss = 0.5476376414299011, validation loss = 0.5561981797218323
# epoch = 27, training loss = 0.5344628691673279, validation loss = 0.5443409085273743
# epoch = 28, training loss = 0.5251756310462952, validation loss = 0.5355172157287598
# epoch = 29, training loss = 0.5042533278465271, validation loss = 0.5165395736694336
# epoch = 30, training loss = 0.4911080002784729, validation loss = 0.505039393901825
# epoch = 31, training loss = 0.4786149859428406, validation loss = 0.4925532937049866
# epoch = 32, training loss = 0.46244052052497864, validation loss = 0.47764575481414795
# epoch = 33, training loss = 0.4478722810745239, validation loss = 0.4643983542919159
# epoch = 34, training loss = 0.43795281648635864, validation loss = 0.4551668167114258
# epoch = 35, training loss = 0.42557740211486816, validation loss = 0.4442489445209503
# epoch = 36, training loss = 0.42284831404685974, validation loss = 0.4408190846443176
# epoch = 37, training loss = 0.4116882383823395, validation loss = 0.4337294399738312
# epoch = 38, training loss = 0.39914369583129883, validation loss = 0.4209230840206146
# epoch = 39, training loss = 0.3967386484146118, validation loss = 0.4201953411102295
# epoch = 40, training loss = 0.389614462852478, validation loss = 0.41122326254844666
# epoch = 41, training loss = 0.3881724178791046, validation loss = 0.410631388425827
# epoch = 42, training loss = 0.3815405070781708, validation loss = 0.40795499086380005
# epoch = 43, training loss = 0.37130171060562134, validation loss = 0.39676395058631897
# epoch = 44, training loss = 0.36810705065727234, validation loss = 0.39498788118362427
# epoch = 45, training loss = 0.36324620246887207, validation loss = 0.39031684398651123
# epoch = 46, training loss = 0.3587440848350525, validation loss = 0.38521847128868103
# epoch = 47, training loss = 0.3570132851600647, validation loss = 0.3826634883880615
# epoch = 48, training loss = 0.3520743250846863, validation loss = 0.37851810455322266
# epoch = 49, training loss = 0.349252313375473, validation loss = 0.37720027565956116
# epoch = 50, training loss = 0.34603744745254517, validation loss = 0.37352219223976135
# epoch = 51, training loss = 0.3419976830482483, validation loss = 0.36903366446495056
# epoch = 52, training loss = 0.34051305055618286, validation loss = 0.36853811144828796
# epoch = 53, training loss = 0.33934980630874634, validation loss = 0.36776983737945557
# epoch = 54, training loss = 0.3376220166683197, validation loss = 0.3638862073421478
# epoch = 55, training loss = 0.33341991901397705, validation loss = 0.3606546223163605
# epoch = 56, training loss = 0.33186227083206177, validation loss = 0.3599514663219452
# epoch = 57, training loss = 0.3314712643623352, validation loss = 0.359743595123291
# epoch = 58, training loss = 0.32901495695114136, validation loss = 0.3563043177127838
# epoch = 59, training loss = 0.32770296931266785, validation loss = 0.3556038737297058
# epoch = 60, training loss = 0.32678741216659546, validation loss = 0.3545236587524414
# epoch = 61, training loss = 0.3279738426208496, validation loss = 0.3568969666957855
# EarlyStopping counter: 1 out of 10
# epoch = 62, training loss = 0.3276543915271759, validation loss = 0.3566470742225647
# EarlyStopping counter: 2 out of 10
# epoch = 63, training loss = 0.32433295249938965, validation loss = 0.3522411286830902
# epoch = 64, training loss = 0.32400205731391907, validation loss = 0.35147666931152344
# epoch = 65, training loss = 0.323411762714386, validation loss = 0.3511110544204712
# epoch = 66, training loss = 0.3252946734428406, validation loss = 0.35246381163597107
# EarlyStopping counter: 1 out of 10
# epoch = 67, training loss = 0.3225187659263611, validation loss = 0.35057690739631653
# epoch = 68, training loss = 0.32198360562324524, validation loss = 0.3505750298500061
# epoch = 69, training loss = 0.32392504811286926, validation loss = 0.3533194065093994
# EarlyStopping counter: 1 out of 10
# epoch = 70, training loss = 0.3213253915309906, validation loss = 0.3491126000881195
# epoch = 71, training loss = 0.320809006690979, validation loss = 0.34937408566474915
# EarlyStopping counter: 1 out of 10
# epoch = 72, training loss = 0.32197991013526917, validation loss = 0.34937527775764465
# EarlyStopping counter: 2 out of 10
# epoch = 73, training loss = 0.32129621505737305, validation loss = 0.35050535202026367
# EarlyStopping counter: 3 out of 10
# epoch = 74, training loss = 0.32238101959228516, validation loss = 0.3498435318470001
# EarlyStopping counter: 4 out of 10
# epoch = 75, training loss = 0.32145774364471436, validation loss = 0.3490475118160248
# epoch = 76, training loss = 0.3203010857105255, validation loss = 0.34819236397743225
# epoch = 77, training loss = 0.3214466869831085, validation loss = 0.3508548438549042
# EarlyStopping counter: 1 out of 10
# epoch = 78, training loss = 0.32210564613342285, validation loss = 0.35183143615722656
# EarlyStopping counter: 2 out of 10
# epoch = 79, training loss = 0.3221448063850403, validation loss = 0.349923312664032
# EarlyStopping counter: 3 out of 10
# epoch = 80, training loss = 0.3188379108905792, validation loss = 0.347164511680603
# epoch = 81, training loss = 0.3203636407852173, validation loss = 0.3497273623943329
# EarlyStopping counter: 1 out of 10
# epoch = 82, training loss = 0.31904858350753784, validation loss = 0.3471861779689789
# EarlyStopping counter: 2 out of 10
# epoch = 83, training loss = 0.3226313292980194, validation loss = 0.3525746166706085
# EarlyStopping counter: 3 out of 10
# epoch = 84, training loss = 0.3245526850223541, validation loss = 0.3514877259731293
# EarlyStopping counter: 4 out of 10
# epoch = 85, training loss = 0.31819039583206177, validation loss = 0.34689101576805115
# epoch = 86, training loss = 0.32105129957199097, validation loss = 0.3510090112686157
# EarlyStopping counter: 1 out of 10
# epoch = 87, training loss = 0.3179934620857239, validation loss = 0.34660425782203674
# epoch = 88, training loss = 0.31825777888298035, validation loss = 0.3473743796348572
# EarlyStopping counter: 1 out of 10
# epoch = 89, training loss = 0.31829342246055603, validation loss = 0.34642183780670166
# epoch = 90, training loss = 0.31860873103141785, validation loss = 0.3478439152240753
# EarlyStopping counter: 1 out of 10
# epoch = 91, training loss = 0.3210107386112213, validation loss = 0.348303884267807
# EarlyStopping counter: 2 out of 10
# epoch = 92, training loss = 0.31768471002578735, validation loss = 0.3462938666343689
# epoch = 93, training loss = 0.31791964173316956, validation loss = 0.3470380902290344
# EarlyStopping counter: 1 out of 10
# epoch = 94, training loss = 0.32504138350486755, validation loss = 0.3553784489631653
# EarlyStopping counter: 2 out of 10
# epoch = 95, training loss = 0.31745973229408264, validation loss = 0.34597504138946533
# epoch = 96, training loss = 0.3176122307777405, validation loss = 0.3458862006664276
# epoch = 97, training loss = 0.3176582157611847, validation loss = 0.34600546956062317
# EarlyStopping counter: 1 out of 10
# epoch = 98, training loss = 0.31853798031806946, validation loss = 0.34645482897758484
# EarlyStopping counter: 2 out of 10
# epoch = 99, training loss = 0.32540541887283325, validation loss = 0.35230785608291626
# EarlyStopping counter: 3 out of 10
# epoch = 100, training loss = 0.3199283480644226, validation loss = 0.3474707007408142
# EarlyStopping counter: 4 out of 10
# epoch = 101, training loss = 0.31747323274612427, validation loss = 0.34582093358039856
# epoch = 102, training loss = 0.31714341044425964, validation loss = 0.34603017568588257
# EarlyStopping counter: 1 out of 10
# epoch = 103, training loss = 0.31704819202423096, validation loss = 0.3457953631877899
# epoch = 104, training loss = 0.31814515590667725, validation loss = 0.3460126519203186
# EarlyStopping counter: 1 out of 10
# epoch = 105, training loss = 0.3231033980846405, validation loss = 0.3534492552280426
# EarlyStopping counter: 2 out of 10
# epoch = 106, training loss = 0.31870490312576294, validation loss = 0.3466813564300537
# EarlyStopping counter: 3 out of 10
# epoch = 107, training loss = 0.317022442817688, validation loss = 0.34567388892173767
# epoch = 108, training loss = 0.3169589638710022, validation loss = 0.3453630208969116
# epoch = 109, training loss = 0.3187323808670044, validation loss = 0.3464118242263794
# EarlyStopping counter: 1 out of 10
# epoch = 110, training loss = 0.32017186284065247, validation loss = 0.35022836923599243
# EarlyStopping counter: 2 out of 10
# epoch = 111, training loss = 0.31713879108428955, validation loss = 0.34612488746643066
# EarlyStopping counter: 3 out of 10
# epoch = 112, training loss = 0.32222339510917664, validation loss = 0.3496389091014862
# EarlyStopping counter: 4 out of 10
# epoch = 113, training loss = 0.3169898986816406, validation loss = 0.34526491165161133
# epoch = 114, training loss = 0.3168002963066101, validation loss = 0.34511175751686096
# epoch = 115, training loss = 0.3166298270225525, validation loss = 0.3451848030090332
# EarlyStopping counter: 1 out of 10
# epoch = 116, training loss = 0.3198726773262024, validation loss = 0.3474275469779968
# EarlyStopping counter: 2 out of 10
# epoch = 117, training loss = 0.316923588514328, validation loss = 0.345088928937912
# epoch = 118, training loss = 0.3169724643230438, validation loss = 0.34504616260528564
# epoch = 119, training loss = 0.31702715158462524, validation loss = 0.34522512555122375
# EarlyStopping counter: 1 out of 10
# epoch = 120, training loss = 0.3169495165348053, validation loss = 0.34545111656188965
# EarlyStopping counter: 2 out of 10
# epoch = 121, training loss = 0.31681573390960693, validation loss = 0.34598204493522644
# EarlyStopping counter: 3 out of 10
# epoch = 122, training loss = 0.320491224527359, validation loss = 0.3505549728870392
# EarlyStopping counter: 4 out of 10
# epoch = 123, training loss = 0.3169746994972229, validation loss = 0.345181941986084
# EarlyStopping counter: 5 out of 10
# epoch = 124, training loss = 0.3218547999858856, validation loss = 0.3522835671901703
# EarlyStopping counter: 6 out of 10
# epoch = 125, training loss = 0.32011649012565613, validation loss = 0.34781745076179504
# EarlyStopping counter: 7 out of 10
# epoch = 126, training loss = 0.3174296021461487, validation loss = 0.34686279296875
# EarlyStopping counter: 8 out of 10
# epoch = 127, training loss = 0.3299644887447357, validation loss = 0.3563864231109619
# EarlyStopping counter: 9 out of 10
# epoch = 128, training loss = 0.31744304299354553, validation loss = 0.34687504172325134
# EarlyStopping counter: 10 out of 10
# Early stopping
# epoch = 0, training loss = 8.205869674682617, validation loss = 8.17648983001709
# epoch = 1, training loss = 0.9428216814994812, validation loss = 0.9354605674743652
# epoch = 2, training loss = 0.6832119822502136, validation loss = 0.6852186322212219
# epoch = 3, training loss = 0.6350263357162476, validation loss = 0.6399012804031372
# epoch = 4, training loss = 0.57466059923172, validation loss = 0.583440363407135
# epoch = 5, training loss = 0.5042275190353394, validation loss = 0.5181610584259033
# epoch = 6, training loss = 0.4449262320995331, validation loss = 0.4640190303325653
# epoch = 7, training loss = 0.4125189185142517, validation loss = 0.4326471984386444
# epoch = 8, training loss = 0.39026954770088196, validation loss = 0.4122387766838074
# epoch = 9, training loss = 0.3739943206310272, validation loss = 0.3945446312427521
# epoch = 10, training loss = 0.35928875207901, validation loss = 0.38122066855430603
# epoch = 11, training loss = 0.34159231185913086, validation loss = 0.36272132396698
# epoch = 12, training loss = 0.3198896646499634, validation loss = 0.33758530020713806
# epoch = 13, training loss = 0.3082858920097351, validation loss = 0.32703515887260437
# epoch = 14, training loss = 0.28378984332084656, validation loss = 0.303703635931015
# epoch = 15, training loss = 0.26456567645072937, validation loss = 0.2839110791683197
# epoch = 16, training loss = 0.26668593287467957, validation loss = 0.28781360387802124
# EarlyStopping counter: 1 out of 10
# epoch = 17, training loss = 0.24726276099681854, validation loss = 0.2677671015262604
# epoch = 18, training loss = 0.24152472615242004, validation loss = 0.2620946764945984
# epoch = 19, training loss = 0.23851993680000305, validation loss = 0.2596711218357086
# epoch = 20, training loss = 0.2426089346408844, validation loss = 0.26228514313697815
# EarlyStopping counter: 1 out of 10
# epoch = 21, training loss = 0.2330348640680313, validation loss = 0.2541149854660034
# epoch = 22, training loss = 0.24165911972522736, validation loss = 0.2617245316505432
# EarlyStopping counter: 1 out of 10
# epoch = 23, training loss = 0.22981183230876923, validation loss = 0.2515003979206085
# epoch = 24, training loss = 0.23098918795585632, validation loss = 0.2526516318321228
# EarlyStopping counter: 1 out of 10
# epoch = 25, training loss = 0.229538694024086, validation loss = 0.24987928569316864
# epoch = 26, training loss = 0.2647865116596222, validation loss = 0.2878580093383789
# EarlyStopping counter: 1 out of 10
# epoch = 27, training loss = 0.22482995688915253, validation loss = 0.2463303953409195
# epoch = 28, training loss = 0.21964897215366364, validation loss = 0.24032080173492432
# epoch = 29, training loss = 0.22032594680786133, validation loss = 0.24024724960327148
# epoch = 30, training loss = 0.2184058576822281, validation loss = 0.2379981279373169
# epoch = 31, training loss = 0.21451449394226074, validation loss = 0.23454880714416504
# epoch = 32, training loss = 0.22220690548419952, validation loss = 0.24317161738872528
# EarlyStopping counter: 1 out of 10
# epoch = 33, training loss = 0.21379218995571136, validation loss = 0.23385390639305115
# epoch = 34, training loss = 0.21926985681056976, validation loss = 0.23914238810539246
# EarlyStopping counter: 1 out of 10
# epoch = 35, training loss = 0.21549925208091736, validation loss = 0.23504258692264557
# EarlyStopping counter: 2 out of 10
# epoch = 36, training loss = 0.21899119019508362, validation loss = 0.24005335569381714
# EarlyStopping counter: 3 out of 10
# epoch = 37, training loss = 0.20515340566635132, validation loss = 0.2244214415550232
# epoch = 38, training loss = 0.20516668260097504, validation loss = 0.22457535564899445
# EarlyStopping counter: 1 out of 10
# epoch = 39, training loss = 0.2038438767194748, validation loss = 0.22337572276592255
# epoch = 40, training loss = 0.21297504007816315, validation loss = 0.23196005821228027
# EarlyStopping counter: 1 out of 10
# epoch = 41, training loss = 0.20101024210453033, validation loss = 0.22022612392902374
# epoch = 42, training loss = 0.2014380842447281, validation loss = 0.2200687825679779
# epoch = 43, training loss = 0.2002732753753662, validation loss = 0.2180922031402588
# epoch = 44, training loss = 0.19743363559246063, validation loss = 0.21538285911083221
# epoch = 45, training loss = 0.2010015845298767, validation loss = 0.21885734796524048
# EarlyStopping counter: 1 out of 10
# epoch = 46, training loss = 0.21034882962703705, validation loss = 0.22832614183425903
# EarlyStopping counter: 2 out of 10
# epoch = 47, training loss = 0.21154557168483734, validation loss = 0.2300853133201599
# EarlyStopping counter: 3 out of 10
# epoch = 48, training loss = 0.1927160620689392, validation loss = 0.21052689850330353
# epoch = 49, training loss = 0.1923617273569107, validation loss = 0.21025621891021729
# epoch = 50, training loss = 0.20597104728221893, validation loss = 0.22391226887702942
# EarlyStopping counter: 1 out of 10
# epoch = 51, training loss = 0.19051694869995117, validation loss = 0.20813363790512085
# epoch = 52, training loss = 0.19209127128124237, validation loss = 0.2092249095439911
# EarlyStopping counter: 1 out of 10
# epoch = 53, training loss = 0.20319731533527374, validation loss = 0.2210552841424942
# EarlyStopping counter: 2 out of 10
# epoch = 54, training loss = 0.19829510152339935, validation loss = 0.21545687317848206
# EarlyStopping counter: 3 out of 10
# epoch = 55, training loss = 0.18933235108852386, validation loss = 0.20671285688877106
# epoch = 56, training loss = 0.21880951523780823, validation loss = 0.23617103695869446
# EarlyStopping counter: 1 out of 10
# epoch = 57, training loss = 0.18614286184310913, validation loss = 0.20284901559352875
# epoch = 58, training loss = 0.18658041954040527, validation loss = 0.20267494022846222
# epoch = 59, training loss = 0.18467819690704346, validation loss = 0.20118099451065063
# epoch = 60, training loss = 0.18504571914672852, validation loss = 0.20163513720035553
# EarlyStopping counter: 1 out of 10
# epoch = 61, training loss = 0.1905229538679123, validation loss = 0.2071465700864792
# EarlyStopping counter: 2 out of 10
# epoch = 62, training loss = 0.1824597865343094, validation loss = 0.1990622729063034
# epoch = 63, training loss = 0.18377219140529633, validation loss = 0.2004862278699875
# EarlyStopping counter: 1 out of 10
# epoch = 64, training loss = 0.19618289172649384, validation loss = 0.2122267186641693
# EarlyStopping counter: 2 out of 10
# epoch = 65, training loss = 0.20373158156871796, validation loss = 0.2204456776380539
# EarlyStopping counter: 3 out of 10
# epoch = 66, training loss = 0.18287287652492523, validation loss = 0.19861102104187012
# epoch = 67, training loss = 0.19309796392917633, validation loss = 0.2088334858417511
# EarlyStopping counter: 1 out of 10
# epoch = 68, training loss = 0.17940102517604828, validation loss = 0.19504566490650177
# epoch = 69, training loss = 0.18761174380779266, validation loss = 0.20367074012756348
# EarlyStopping counter: 1 out of 10
# epoch = 70, training loss = 0.18339669704437256, validation loss = 0.19878710806369781
# EarlyStopping counter: 2 out of 10
# epoch = 71, training loss = 0.17765747010707855, validation loss = 0.19313396513462067
# epoch = 72, training loss = 0.17688649892807007, validation loss = 0.19294650852680206
# epoch = 73, training loss = 0.17761050164699554, validation loss = 0.19290947914123535
# epoch = 74, training loss = 0.17800959944725037, validation loss = 0.193331778049469
# EarlyStopping counter: 1 out of 10
# epoch = 75, training loss = 0.1770891398191452, validation loss = 0.19228829443454742
# epoch = 76, training loss = 0.17256392538547516, validation loss = 0.18729494512081146
# epoch = 77, training loss = 0.1834632158279419, validation loss = 0.19878971576690674
# EarlyStopping counter: 1 out of 10
# epoch = 78, training loss = 0.1829511672258377, validation loss = 0.1973314732313156
# EarlyStopping counter: 2 out of 10
# epoch = 79, training loss = 0.17154422402381897, validation loss = 0.1861836016178131
# epoch = 80, training loss = 0.17046554386615753, validation loss = 0.18479345738887787
# epoch = 81, training loss = 0.1682378053665161, validation loss = 0.18250785768032074
# epoch = 82, training loss = 0.17062073945999146, validation loss = 0.18486206233501434
# EarlyStopping counter: 1 out of 10
# epoch = 83, training loss = 0.16747090220451355, validation loss = 0.1811264455318451
# epoch = 84, training loss = 0.16654261946678162, validation loss = 0.1801927089691162
# epoch = 85, training loss = 0.17370125651359558, validation loss = 0.18710388243198395
# EarlyStopping counter: 1 out of 10
# epoch = 86, training loss = 0.1647617369890213, validation loss = 0.17808754742145538
# epoch = 87, training loss = 0.16608349978923798, validation loss = 0.17990340292453766
# EarlyStopping counter: 1 out of 10
# epoch = 88, training loss = 0.1652178168296814, validation loss = 0.17852643132209778
# EarlyStopping counter: 2 out of 10
# epoch = 89, training loss = 0.16199569404125214, validation loss = 0.17526866495609283
# epoch = 90, training loss = 0.16140630841255188, validation loss = 0.17436397075653076
# epoch = 91, training loss = 0.16121307015419006, validation loss = 0.17464956641197205
# EarlyStopping counter: 1 out of 10
# epoch = 92, training loss = 0.16675710678100586, validation loss = 0.1797562688589096
# EarlyStopping counter: 2 out of 10
# epoch = 93, training loss = 0.15997707843780518, validation loss = 0.17294174432754517
# epoch = 94, training loss = 0.15684965252876282, validation loss = 0.16946658492088318
# epoch = 95, training loss = 0.1558203399181366, validation loss = 0.16858340799808502
# epoch = 96, training loss = 0.15752047300338745, validation loss = 0.17028845846652985
# EarlyStopping counter: 1 out of 10
# epoch = 97, training loss = 0.1658037006855011, validation loss = 0.17823739349842072
# EarlyStopping counter: 2 out of 10
# epoch = 98, training loss = 0.16972830891609192, validation loss = 0.1817527562379837
# EarlyStopping counter: 3 out of 10
# epoch = 99, training loss = 0.15292581915855408, validation loss = 0.16487468779087067
# epoch = 100, training loss = 0.16297198832035065, validation loss = 0.17492835223674774
# EarlyStopping counter: 1 out of 10
# epoch = 101, training loss = 0.15131892263889313, validation loss = 0.16319090127944946
# epoch = 102, training loss = 0.15951718389987946, validation loss = 0.17152082920074463
# EarlyStopping counter: 1 out of 10
# epoch = 103, training loss = 0.15204539895057678, validation loss = 0.16379500925540924
# EarlyStopping counter: 2 out of 10
# epoch = 104, training loss = 0.1502542346715927, validation loss = 0.16170576214790344
# epoch = 105, training loss = 0.1538883000612259, validation loss = 0.16568155586719513
# EarlyStopping counter: 1 out of 10
# epoch = 106, training loss = 0.14843907952308655, validation loss = 0.15956981480121613
# epoch = 107, training loss = 0.15791964530944824, validation loss = 0.16963686048984528
# EarlyStopping counter: 1 out of 10
# epoch = 108, training loss = 0.14866824448108673, validation loss = 0.16016201674938202
# EarlyStopping counter: 2 out of 10
# epoch = 109, training loss = 0.16301384568214417, validation loss = 0.1742877960205078
# EarlyStopping counter: 3 out of 10
# epoch = 110, training loss = 0.15235111117362976, validation loss = 0.1635279506444931
# EarlyStopping counter: 4 out of 10
# epoch = 111, training loss = 0.15063126385211945, validation loss = 0.16192865371704102
# EarlyStopping counter: 5 out of 10
# epoch = 112, training loss = 0.14488258957862854, validation loss = 0.15630759298801422
# epoch = 113, training loss = 0.1622970849275589, validation loss = 0.17407016456127167
# EarlyStopping counter: 1 out of 10
# epoch = 114, training loss = 0.16672544181346893, validation loss = 0.17782533168792725
# EarlyStopping counter: 2 out of 10
# epoch = 115, training loss = 0.14334197342395782, validation loss = 0.1539493352174759
# epoch = 116, training loss = 0.1442619413137436, validation loss = 0.15524129569530487
# EarlyStopping counter: 1 out of 10
# epoch = 117, training loss = 0.1417824774980545, validation loss = 0.1524861752986908
# epoch = 118, training loss = 0.14159660041332245, validation loss = 0.15266720950603485
# EarlyStopping counter: 1 out of 10
# epoch = 119, training loss = 0.14155806601047516, validation loss = 0.15225517749786377
# epoch = 120, training loss = 0.14904329180717468, validation loss = 0.15986090898513794
# EarlyStopping counter: 1 out of 10
# epoch = 121, training loss = 0.16599440574645996, validation loss = 0.17664028704166412
# EarlyStopping counter: 2 out of 10
# epoch = 122, training loss = 0.13887333869934082, validation loss = 0.14892560243606567
# epoch = 123, training loss = 0.14886540174484253, validation loss = 0.1598518192768097
# EarlyStopping counter: 1 out of 10
# epoch = 124, training loss = 0.1424601972103119, validation loss = 0.15260039269924164
# EarlyStopping counter: 2 out of 10
# epoch = 125, training loss = 0.1360263228416443, validation loss = 0.1465078741312027
# epoch = 126, training loss = 0.14205406606197357, validation loss = 0.15259340405464172
# EarlyStopping counter: 1 out of 10
# epoch = 127, training loss = 0.15439066290855408, validation loss = 0.16543284058570862
# EarlyStopping counter: 2 out of 10
# epoch = 128, training loss = 0.1354774683713913, validation loss = 0.14591915905475616
# epoch = 129, training loss = 0.13325583934783936, validation loss = 0.1437697559595108
# epoch = 130, training loss = 0.14372526109218597, validation loss = 0.15433676540851593
# EarlyStopping counter: 1 out of 10
# epoch = 131, training loss = 0.13739006221294403, validation loss = 0.14754606783390045
# EarlyStopping counter: 2 out of 10
# epoch = 132, training loss = 0.13389290869235992, validation loss = 0.14447790384292603
# EarlyStopping counter: 3 out of 10
# epoch = 133, training loss = 0.13250412046909332, validation loss = 0.14286546409130096
# epoch = 134, training loss = 0.13151657581329346, validation loss = 0.14217182993888855
# epoch = 135, training loss = 0.13271260261535645, validation loss = 0.1431785523891449
# EarlyStopping counter: 1 out of 10
# epoch = 136, training loss = 0.1514049768447876, validation loss = 0.1633693128824234
# EarlyStopping counter: 2 out of 10
# epoch = 137, training loss = 0.13081209361553192, validation loss = 0.14181171357631683
# epoch = 138, training loss = 0.14767374098300934, validation loss = 0.15859277546405792
# EarlyStopping counter: 1 out of 10
# epoch = 139, training loss = 0.12875747680664062, validation loss = 0.1394093781709671
# epoch = 140, training loss = 0.13124753534793854, validation loss = 0.141973614692688
# EarlyStopping counter: 1 out of 10
# epoch = 141, training loss = 0.1300383359193802, validation loss = 0.1408572643995285
# EarlyStopping counter: 2 out of 10
# epoch = 142, training loss = 0.12589947879314423, validation loss = 0.13678929209709167
# epoch = 143, training loss = 0.12565207481384277, validation loss = 0.13619853556156158
# epoch = 144, training loss = 0.1266774982213974, validation loss = 0.13756011426448822
# EarlyStopping counter: 1 out of 10
# epoch = 145, training loss = 0.13193194568157196, validation loss = 0.14221039414405823
# EarlyStopping counter: 2 out of 10
# epoch = 146, training loss = 0.12486283481121063, validation loss = 0.13561353087425232
# epoch = 147, training loss = 0.12311441451311111, validation loss = 0.13334502279758453
# epoch = 148, training loss = 0.12391006946563721, validation loss = 0.13452297449111938
# EarlyStopping counter: 1 out of 10
# epoch = 149, training loss = 0.12393324077129364, validation loss = 0.1347205638885498
# EarlyStopping counter: 2 out of 10
# epoch = 150, training loss = 0.12981310486793518, validation loss = 0.14029087126255035
# EarlyStopping counter: 3 out of 10
# epoch = 151, training loss = 0.12277564406394958, validation loss = 0.1335507184267044
# EarlyStopping counter: 4 out of 10
# epoch = 152, training loss = 0.12036249786615372, validation loss = 0.13078650832176208
# epoch = 153, training loss = 0.12674029171466827, validation loss = 0.1375199407339096
# EarlyStopping counter: 1 out of 10
# epoch = 154, training loss = 0.11831469088792801, validation loss = 0.12877431511878967
# epoch = 155, training loss = 0.12605547904968262, validation loss = 0.1365436464548111
# EarlyStopping counter: 1 out of 10
# epoch = 156, training loss = 0.12672872841358185, validation loss = 0.13661007583141327
# EarlyStopping counter: 2 out of 10
# epoch = 157, training loss = 0.11787466704845428, validation loss = 0.1284867227077484
# epoch = 158, training loss = 0.11736530810594559, validation loss = 0.1275143027305603
# epoch = 159, training loss = 0.14565496146678925, validation loss = 0.15548712015151978
# EarlyStopping counter: 1 out of 10
# epoch = 160, training loss = 0.11737341433763504, validation loss = 0.12794053554534912
# EarlyStopping counter: 2 out of 10
# epoch = 161, training loss = 0.11958615481853485, validation loss = 0.13032937049865723
# EarlyStopping counter: 3 out of 10
# epoch = 162, training loss = 0.13847213983535767, validation loss = 0.14860501885414124
# EarlyStopping counter: 4 out of 10
# epoch = 163, training loss = 0.11639458686113358, validation loss = 0.12702390551567078
# epoch = 164, training loss = 0.11773358285427094, validation loss = 0.1274157166481018
# EarlyStopping counter: 1 out of 10
# epoch = 165, training loss = 0.12668725848197937, validation loss = 0.1367349624633789
# EarlyStopping counter: 2 out of 10
# epoch = 166, training loss = 0.11422555148601532, validation loss = 0.12471043318510056
# epoch = 167, training loss = 0.11529525369405746, validation loss = 0.12587951123714447
# EarlyStopping counter: 1 out of 10
# epoch = 168, training loss = 0.11356858164072037, validation loss = 0.12392696738243103
# epoch = 169, training loss = 0.1273115873336792, validation loss = 0.13739868998527527
# EarlyStopping counter: 1 out of 10
# epoch = 170, training loss = 0.11525917798280716, validation loss = 0.12525463104248047
# EarlyStopping counter: 2 out of 10
# epoch = 171, training loss = 0.11413824558258057, validation loss = 0.12415815144777298
# EarlyStopping counter: 3 out of 10
# epoch = 172, training loss = 0.1300755739212036, validation loss = 0.1412992626428604
# EarlyStopping counter: 4 out of 10
# epoch = 173, training loss = 0.11915500462055206, validation loss = 0.13017764687538147
# EarlyStopping counter: 5 out of 10
# epoch = 174, training loss = 0.1182876005768776, validation loss = 0.12909741699695587
# EarlyStopping counter: 6 out of 10
# epoch = 175, training loss = 0.11630970984697342, validation loss = 0.12607043981552124
# EarlyStopping counter: 7 out of 10
# epoch = 176, training loss = 0.1160833016037941, validation loss = 0.12657278776168823
# EarlyStopping counter: 8 out of 10
# epoch = 177, training loss = 0.1122395247220993, validation loss = 0.1217605322599411
# epoch = 178, training loss = 0.14555490016937256, validation loss = 0.15444672107696533
# EarlyStopping counter: 1 out of 10
# epoch = 179, training loss = 0.112213134765625, validation loss = 0.12210643291473389
# EarlyStopping counter: 2 out of 10
# epoch = 180, training loss = 0.11843669414520264, validation loss = 0.12804743647575378
# EarlyStopping counter: 3 out of 10
# epoch = 181, training loss = 0.11898697912693024, validation loss = 0.12839506566524506
# EarlyStopping counter: 4 out of 10
# epoch = 182, training loss = 0.12385091185569763, validation loss = 0.13460898399353027
# EarlyStopping counter: 5 out of 10
# epoch = 183, training loss = 0.11127666383981705, validation loss = 0.12118913233280182
# epoch = 184, training loss = 0.10968188941478729, validation loss = 0.1197349950671196
# epoch = 185, training loss = 0.11230220645666122, validation loss = 0.12176289409399033
# EarlyStopping counter: 1 out of 10
# epoch = 186, training loss = 0.1316673457622528, validation loss = 0.14066842198371887
# EarlyStopping counter: 2 out of 10
# epoch = 187, training loss = 0.12590688467025757, validation loss = 0.1355741024017334
# EarlyStopping counter: 3 out of 10
# epoch = 188, training loss = 0.10990176349878311, validation loss = 0.11999621987342834
# EarlyStopping counter: 4 out of 10
# epoch = 189, training loss = 0.11346375942230225, validation loss = 0.12382694333791733
# EarlyStopping counter: 5 out of 10
# epoch = 190, training loss = 0.11138433963060379, validation loss = 0.12172117829322815
# EarlyStopping counter: 6 out of 10
# epoch = 191, training loss = 0.1446392983198166, validation loss = 0.15306724607944489
# EarlyStopping counter: 7 out of 10
# epoch = 192, training loss = 0.13339988887310028, validation loss = 0.14510296285152435
# EarlyStopping counter: 8 out of 10
# epoch = 193, training loss = 0.10874348878860474, validation loss = 0.11842534691095352
# epoch = 194, training loss = 0.10772338509559631, validation loss = 0.11775410175323486
# epoch = 195, training loss = 0.11252928525209427, validation loss = 0.1230291798710823
# EarlyStopping counter: 1 out of 10
# epoch = 196, training loss = 0.10865779966115952, validation loss = 0.11885122209787369
# EarlyStopping counter: 2 out of 10
# epoch = 197, training loss = 0.10975475609302521, validation loss = 0.11957519501447678
# EarlyStopping counter: 3 out of 10
# epoch = 198, training loss = 0.11480765789747238, validation loss = 0.12405043840408325
# EarlyStopping counter: 4 out of 10
# epoch = 199, training loss = 0.10873228311538696, validation loss = 0.11838528513908386
# EarlyStopping counter: 5 out of 10
# epoch = 200, training loss = 0.13583694398403168, validation loss = 0.14705818891525269
# EarlyStopping counter: 6 out of 10
# epoch = 201, training loss = 0.1094026118516922, validation loss = 0.11928310990333557
# EarlyStopping counter: 7 out of 10
# epoch = 202, training loss = 0.10993784666061401, validation loss = 0.1193467304110527
# EarlyStopping counter: 8 out of 10
# epoch = 203, training loss = 0.11482831835746765, validation loss = 0.12424950301647186
# EarlyStopping counter: 9 out of 10
# epoch = 204, training loss = 0.1310568004846573, validation loss = 0.14250870048999786
# EarlyStopping counter: 10 out of 10
# Early stopping
# epoch = 0, training loss = 0.798121452331543, validation loss = 0.7965741157531738
# epoch = 1, training loss = 0.35476547479629517, validation loss = 0.37451764941215515
# epoch = 2, training loss = 0.2304275631904602, validation loss = 0.25834402441978455
# epoch = 3, training loss = 0.21020960807800293, validation loss = 0.23650100827217102
# epoch = 4, training loss = 0.1995667964220047, validation loss = 0.2236044853925705
# epoch = 5, training loss = 0.19215098023414612, validation loss = 0.2153111845254898
# epoch = 6, training loss = 0.189704030752182, validation loss = 0.21243800222873688
# epoch = 7, training loss = 0.17694765329360962, validation loss = 0.19653065502643585
# epoch = 8, training loss = 0.16763578355312347, validation loss = 0.18567414581775665
# epoch = 9, training loss = 0.16874511539936066, validation loss = 0.18432116508483887
# epoch = 10, training loss = 0.15004317462444305, validation loss = 0.16600021719932556
# epoch = 11, training loss = 0.150294229388237, validation loss = 0.16764460504055023
# epoch = 12, training loss = 0.13573291897773743, validation loss = 0.1511935442686081
# epoch = 13, training loss = 0.13059085607528687, validation loss = 0.1451103687286377
# epoch = 14, training loss = 0.12471038848161697, validation loss = 0.137760728597641
# epoch = 15, training loss = 0.1242230236530304, validation loss = 0.13748657703399658
# epoch = 16, training loss = 0.12307913601398468, validation loss = 0.13278567790985107
# epoch = 17, training loss = 0.12072266638278961, validation loss = 0.13057924807071686
# epoch = 18, training loss = 0.11438027769327164, validation loss = 0.12590505182743073
# epoch = 19, training loss = 0.12689177691936493, validation loss = 0.13413004577159882
# EarlyStopping counter: 1 out of 10
# epoch = 20, training loss = 0.10351656377315521, validation loss = 0.11249138414859772
# epoch = 21, training loss = 0.10273201018571854, validation loss = 0.1108623594045639
# epoch = 22, training loss = 0.11117541790008545, validation loss = 0.12156384438276291
# EarlyStopping counter: 1 out of 10
# epoch = 23, training loss = 0.10333780944347382, validation loss = 0.11294319480657578
# EarlyStopping counter: 2 out of 10
# epoch = 24, training loss = 0.09567268192768097, validation loss = 0.10363907366991043
# epoch = 25, training loss = 0.15158113837242126, validation loss = 0.15733523666858673
# EarlyStopping counter: 1 out of 10
# epoch = 26, training loss = 0.15019842982292175, validation loss = 0.16312344372272491
# EarlyStopping counter: 2 out of 10
# epoch = 27, training loss = 0.09233665466308594, validation loss = 0.10057435184717178
# epoch = 28, training loss = 0.13018891215324402, validation loss = 0.1365049183368683
# EarlyStopping counter: 1 out of 10
# epoch = 29, training loss = 0.09066818654537201, validation loss = 0.09833647310733795
# epoch = 30, training loss = 0.09694363921880722, validation loss = 0.10655823349952698
# EarlyStopping counter: 1 out of 10
# epoch = 31, training loss = 0.09235914051532745, validation loss = 0.1017477735877037
# EarlyStopping counter: 2 out of 10
# epoch = 32, training loss = 0.09392476826906204, validation loss = 0.10445915162563324
# EarlyStopping counter: 3 out of 10
# epoch = 33, training loss = 0.10916697233915329, validation loss = 0.11612255871295929
# EarlyStopping counter: 4 out of 10
# epoch = 34, training loss = 0.08407452702522278, validation loss = 0.09292662143707275
# epoch = 35, training loss = 0.09150300174951553, validation loss = 0.10100679099559784
# EarlyStopping counter: 1 out of 10
# epoch = 36, training loss = 0.08551651984453201, validation loss = 0.09499508887529373
# EarlyStopping counter: 2 out of 10
# epoch = 37, training loss = 0.08563930541276932, validation loss = 0.09634485840797424
# EarlyStopping counter: 3 out of 10
# epoch = 38, training loss = 0.08388429880142212, validation loss = 0.09203241765499115
# epoch = 39, training loss = 0.10985603928565979, validation loss = 0.11683180183172226
# EarlyStopping counter: 1 out of 10
# epoch = 40, training loss = 0.08261105418205261, validation loss = 0.09162675589323044
# epoch = 41, training loss = 0.09524866193532944, validation loss = 0.10621928423643112
# EarlyStopping counter: 1 out of 10
# epoch = 42, training loss = 0.08531587570905685, validation loss = 0.0927746519446373
# EarlyStopping counter: 2 out of 10
# epoch = 43, training loss = 0.09241753816604614, validation loss = 0.10319653153419495
# EarlyStopping counter: 3 out of 10
# epoch = 44, training loss = 0.08812941610813141, validation loss = 0.09858998656272888
# EarlyStopping counter: 4 out of 10
# epoch = 45, training loss = 0.07761041074991226, validation loss = 0.08579494059085846
# epoch = 46, training loss = 0.09378615766763687, validation loss = 0.10499417036771774
# EarlyStopping counter: 1 out of 10
# epoch = 47, training loss = 0.07965225726366043, validation loss = 0.08881832659244537
# EarlyStopping counter: 2 out of 10
# epoch = 48, training loss = 0.14063745737075806, validation loss = 0.14725331962108612
# EarlyStopping counter: 3 out of 10
# epoch = 49, training loss = 0.12217085808515549, validation loss = 0.13565602898597717
# EarlyStopping counter: 4 out of 10
# epoch = 50, training loss = 0.08177892863750458, validation loss = 0.08956030011177063
# EarlyStopping counter: 5 out of 10
# epoch = 51, training loss = 0.08577936887741089, validation loss = 0.09655357152223587
# EarlyStopping counter: 6 out of 10
# epoch = 52, training loss = 0.07521657645702362, validation loss = 0.0842379480600357
# epoch = 53, training loss = 0.0765240415930748, validation loss = 0.0861031711101532
# EarlyStopping counter: 1 out of 10
# epoch = 54, training loss = 0.07728178054094315, validation loss = 0.08531021326780319
# EarlyStopping counter: 2 out of 10
# epoch = 55, training loss = 0.0784866213798523, validation loss = 0.08694292604923248
# EarlyStopping counter: 3 out of 10
# epoch = 56, training loss = 0.11978597193956375, validation loss = 0.12485983222723007
# EarlyStopping counter: 4 out of 10
# epoch = 57, training loss = 0.08191070705652237, validation loss = 0.09239400923252106
# EarlyStopping counter: 5 out of 10
# epoch = 58, training loss = 0.07495953142642975, validation loss = 0.0836237221956253
# epoch = 59, training loss = 0.09702450037002563, validation loss = 0.10351572185754776
# EarlyStopping counter: 1 out of 10
# epoch = 60, training loss = 0.07724177092313766, validation loss = 0.0854245275259018
# EarlyStopping counter: 2 out of 10
# epoch = 61, training loss = 0.07395870983600616, validation loss = 0.082530178129673
# epoch = 62, training loss = 0.07633982598781586, validation loss = 0.0852733701467514
# EarlyStopping counter: 1 out of 10
# epoch = 63, training loss = 0.08947813510894775, validation loss = 0.10061074048280716
# EarlyStopping counter: 2 out of 10
# epoch = 64, training loss = 0.07400068640708923, validation loss = 0.08344695717096329
# EarlyStopping counter: 3 out of 10
# epoch = 65, training loss = 0.07521095126867294, validation loss = 0.08454080671072006
# EarlyStopping counter: 4 out of 10
# epoch = 66, training loss = 0.07468700408935547, validation loss = 0.08264046907424927
# EarlyStopping counter: 5 out of 10
# epoch = 67, training loss = 0.08967464417219162, validation loss = 0.09706784039735794
# EarlyStopping counter: 6 out of 10
# epoch = 68, training loss = 0.08213620632886887, validation loss = 0.09284421801567078
# EarlyStopping counter: 7 out of 10
# epoch = 69, training loss = 0.10755400359630585, validation loss = 0.1192183643579483
# EarlyStopping counter: 8 out of 10
# epoch = 70, training loss = 0.09260930866003036, validation loss = 0.09939806908369064
# EarlyStopping counter: 9 out of 10
# epoch = 71, training loss = 0.1401650756597519, validation loss = 0.1456514596939087
# EarlyStopping counter: 10 out of 10
# Early stopping
# epoch = 0, training loss = 0.23292382061481476, validation loss = 0.2607277035713196
# epoch = 1, training loss = 0.18819698691368103, validation loss = 0.21304285526275635
# epoch = 2, training loss = 0.16412554681301117, validation loss = 0.18297293782234192
# epoch = 3, training loss = 0.13461534678936005, validation loss = 0.15355826914310455
# epoch = 4, training loss = 0.11734330654144287, validation loss = 0.13413693010807037
# epoch = 5, training loss = 0.10438808053731918, validation loss = 0.11708001047372818
# epoch = 6, training loss = 0.1518181413412094, validation loss = 0.1672888696193695
# epoch = 7, training loss = 0.11597029864788055, validation loss = 0.12994597852230072
# epoch = 8, training loss = 0.12659509479999542, validation loss = 0.13427339494228363
# epoch = 9, training loss = 0.0904860869050026, validation loss = 0.09912893921136856
# epoch = 10, training loss = 0.09899207949638367, validation loss = 0.10686875134706497
# epoch = 11, training loss = 0.07423815131187439, validation loss = 0.08432621508836746
# epoch = 12, training loss = 0.25960081815719604, validation loss = 0.27951779961586
# EarlyStopping counter: 1 out of 10
# epoch = 13, training loss = 0.10169270634651184, validation loss = 0.10883397608995438
# EarlyStopping counter: 2 out of 10
# epoch = 14, training loss = 0.07713662832975388, validation loss = 0.0860615074634552
# EarlyStopping counter: 3 out of 10
# epoch = 15, training loss = 0.07958847284317017, validation loss = 0.09112278372049332
# EarlyStopping counter: 4 out of 10
# epoch = 16, training loss = 0.07301246374845505, validation loss = 0.08283375948667526
# epoch = 17, training loss = 0.09061864018440247, validation loss = 0.0978919118642807
# EarlyStopping counter: 1 out of 10
# epoch = 18, training loss = 0.11175550520420074, validation loss = 0.11703895777463913
# EarlyStopping counter: 2 out of 10
# epoch = 19, training loss = 0.1496249884366989, validation loss = 0.16481101512908936
# EarlyStopping counter: 3 out of 10
# epoch = 20, training loss = 0.08967754244804382, validation loss = 0.0967000350356102
# EarlyStopping counter: 4 out of 10
# epoch = 21, training loss = 0.17241600155830383, validation loss = 0.17594483494758606
# EarlyStopping counter: 5 out of 10
# epoch = 22, training loss = 0.06637513637542725, validation loss = 0.07534826546907425
# epoch = 23, training loss = 0.09078814834356308, validation loss = 0.10222974419593811
# EarlyStopping counter: 1 out of 10
# epoch = 24, training loss = 0.06581727415323257, validation loss = 0.07531055808067322
# epoch = 25, training loss = 0.20031528174877167, validation loss = 0.20212580263614655
# EarlyStopping counter: 1 out of 10
# epoch = 26, training loss = 0.06441351771354675, validation loss = 0.07356966286897659
# epoch = 27, training loss = 0.06992316991090775, validation loss = 0.07779837399721146
# EarlyStopping counter: 1 out of 10
# epoch = 28, training loss = 0.1814255714416504, validation loss = 0.19771601259708405
# EarlyStopping counter: 2 out of 10
# epoch = 29, training loss = 0.08900696039199829, validation loss = 0.10008853673934937
# EarlyStopping counter: 3 out of 10
# epoch = 30, training loss = 0.13547778129577637, validation loss = 0.1392488330602646
# EarlyStopping counter: 4 out of 10
# epoch = 31, training loss = 0.06614968925714493, validation loss = 0.07400975376367569
# EarlyStopping counter: 5 out of 10
# epoch = 32, training loss = 0.07261176407337189, validation loss = 0.08068432658910751
# EarlyStopping counter: 6 out of 10
# epoch = 33, training loss = 0.06290902942419052, validation loss = 0.07193326205015182
# epoch = 34, training loss = 0.09746864438056946, validation loss = 0.10860469937324524
# EarlyStopping counter: 1 out of 10
# epoch = 35, training loss = 0.10968708992004395, validation loss = 0.1216065064072609
# EarlyStopping counter: 2 out of 10
# epoch = 36, training loss = 0.1261267066001892, validation loss = 0.1402224600315094
# EarlyStopping counter: 3 out of 10
# epoch = 37, training loss = 0.0671766847372055, validation loss = 0.07648595422506332
# EarlyStopping counter: 4 out of 10
# epoch = 38, training loss = 0.42481186985969543, validation loss = 0.4435557425022125
# EarlyStopping counter: 5 out of 10
# epoch = 39, training loss = 0.0678391382098198, validation loss = 0.07802721112966537
# EarlyStopping counter: 6 out of 10
# epoch = 40, training loss = 0.08602004498243332, validation loss = 0.0973040908575058
# EarlyStopping counter: 7 out of 10
# epoch = 41, training loss = 0.06477224081754684, validation loss = 0.07453713566064835
# EarlyStopping counter: 8 out of 10
# epoch = 42, training loss = 0.1303476095199585, validation loss = 0.1429915428161621
# EarlyStopping counter: 9 out of 10
# epoch = 43, training loss = 0.0927649438381195, validation loss = 0.1048714891076088
# EarlyStopping counter: 10 out of 10
# Early stopping
# epoch = 0, training loss = 0.2696768045425415, validation loss = 0.299793541431427
# epoch = 1, training loss = 0.21519213914871216, validation loss = 0.24189671874046326
# epoch = 2, training loss = 0.1818847507238388, validation loss = 0.202599436044693
# epoch = 3, training loss = 0.3826034367084503, validation loss = 0.41348695755004883
# epoch = 4, training loss = 0.13128085434436798, validation loss = 0.14817404747009277
# epoch = 5, training loss = 0.1161741241812706, validation loss = 0.12993544340133667
# epoch = 6, training loss = 0.14350929856300354, validation loss = 0.15338917076587677
# epoch = 7, training loss = 0.1324893683195114, validation loss = 0.1416659951210022
# epoch = 8, training loss = 0.10666155815124512, validation loss = 0.11948633939027786
# epoch = 9, training loss = 0.3872078061103821, validation loss = 0.3883934020996094
# epoch = 10, training loss = 0.2713383734226227, validation loss = 0.28735268115997314
# epoch = 11, training loss = 0.12592366337776184, validation loss = 0.13938087224960327
# epoch = 12, training loss = 0.3289553225040436, validation loss = 0.3318995535373688
# EarlyStopping counter: 1 out of 10
# epoch = 13, training loss = 0.15883156657218933, validation loss = 0.1717856228351593
# EarlyStopping counter: 2 out of 10
# epoch = 14, training loss = 0.34903037548065186, validation loss = 0.36912938952445984
# EarlyStopping counter: 3 out of 10
# epoch = 15, training loss = 0.08015245944261551, validation loss = 0.08874581754207611
# epoch = 16, training loss = 0.09010548144578934, validation loss = 0.09732120484113693
# EarlyStopping counter: 1 out of 10
# epoch = 17, training loss = 0.11205963790416718, validation loss = 0.1187751442193985
# EarlyStopping counter: 2 out of 10
# epoch = 18, training loss = 0.07526138424873352, validation loss = 0.08445320278406143
# epoch = 19, training loss = 0.14874371886253357, validation loss = 0.1527067869901657
# EarlyStopping counter: 1 out of 10
# epoch = 20, training loss = 0.07330437749624252, validation loss = 0.08253608644008636
# epoch = 21, training loss = 0.31003934144973755, validation loss = 0.3122326731681824
# EarlyStopping counter: 1 out of 10
# epoch = 22, training loss = 0.08239032328128815, validation loss = 0.08973289281129837
# EarlyStopping counter: 2 out of 10
# epoch = 23, training loss = 0.06887209415435791, validation loss = 0.07760007679462433
# epoch = 24, training loss = 0.22283069789409637, validation loss = 0.23651531338691711
# EarlyStopping counter: 1 out of 10
# epoch = 25, training loss = 0.06944122910499573, validation loss = 0.07814960181713104
# EarlyStopping counter: 2 out of 10
# epoch = 26, training loss = 0.06822098046541214, validation loss = 0.07650534808635712
# epoch = 27, training loss = 0.17526796460151672, validation loss = 0.1902174949645996
# EarlyStopping counter: 1 out of 10
# epoch = 28, training loss = 0.09805653989315033, validation loss = 0.10928411036729813
# EarlyStopping counter: 2 out of 10
# epoch = 29, training loss = 0.09212014824151993, validation loss = 0.10272237658500671
# EarlyStopping counter: 3 out of 10
# epoch = 30, training loss = 0.12270035594701767, validation loss = 0.1273445188999176
# EarlyStopping counter: 4 out of 10
# epoch = 31, training loss = 1.2425990104675293, validation loss = 1.2741217613220215
# EarlyStopping counter: 5 out of 10
# epoch = 32, training loss = 0.06627115607261658, validation loss = 0.07472624629735947
# epoch = 33, training loss = 0.09337344020605087, validation loss = 0.10476870834827423
# EarlyStopping counter: 1 out of 10
# epoch = 34, training loss = 0.11877331882715225, validation loss = 0.1296861618757248
# EarlyStopping counter: 2 out of 10
# epoch = 35, training loss = 0.34181293845176697, validation loss = 0.356405109167099
# EarlyStopping counter: 3 out of 10
# epoch = 36, training loss = 0.1090773269534111, validation loss = 0.1205911710858345
# EarlyStopping counter: 4 out of 10
# epoch = 37, training loss = 0.1275390386581421, validation loss = 0.1426265984773636
# EarlyStopping counter: 5 out of 10
# epoch = 38, training loss = 0.2614215314388275, validation loss = 0.2763485610485077
# EarlyStopping counter: 6 out of 10
# epoch = 39, training loss = 0.06322772800922394, validation loss = 0.07206866890192032
# epoch = 40, training loss = 0.11040952056646347, validation loss = 0.11537475138902664
# EarlyStopping counter: 1 out of 10
# epoch = 41, training loss = 0.29610496759414673, validation loss = 0.2982722222805023
# EarlyStopping counter: 2 out of 10
# epoch = 42, training loss = 0.11567879468202591, validation loss = 0.12753182649612427
# EarlyStopping counter: 3 out of 10
# epoch = 43, training loss = 0.06644544750452042, validation loss = 0.07455416023731232
# EarlyStopping counter: 4 out of 10
# epoch = 44, training loss = 0.060831837356090546, validation loss = 0.06951764225959778
# epoch = 45, training loss = 0.08052918314933777, validation loss = 0.08672888576984406
# EarlyStopping counter: 1 out of 10
# epoch = 46, training loss = 0.06772927939891815, validation loss = 0.0759291723370552
# EarlyStopping counter: 2 out of 10
# epoch = 47, training loss = 0.08435091376304626, validation loss = 0.09001318365335464
# EarlyStopping counter: 3 out of 10
# epoch = 48, training loss = 0.06831447780132294, validation loss = 0.07536321133375168
# EarlyStopping counter: 4 out of 10
# epoch = 49, training loss = 0.10547798126935959, validation loss = 0.1095481812953949
# EarlyStopping counter: 5 out of 10
# epoch = 50, training loss = 0.07566144317388535, validation loss = 0.08222627639770508
# EarlyStopping counter: 6 out of 10
# epoch = 51, training loss = 0.06618133932352066, validation loss = 0.07332251220941544
# EarlyStopping counter: 7 out of 10
# epoch = 52, training loss = 0.18397900462150574, validation loss = 0.18630297482013702
# EarlyStopping counter: 8 out of 10
# epoch = 53, training loss = 0.17557653784751892, validation loss = 0.17830206453800201
# EarlyStopping counter: 9 out of 10
# epoch = 54, training loss = 0.15453681349754333, validation loss = 0.15771102905273438
# EarlyStopping counter: 10 out of 10
# Early stopping
# epoch = 0, training loss = 0.2454475611448288, validation loss = 0.2717278003692627
# epoch = 1, training loss = 0.1892355978488922, validation loss = 0.20903168618679047
# epoch = 2, training loss = 0.15573152899742126, validation loss = 0.17564646899700165
# epoch = 3, training loss = 0.12907707691192627, validation loss = 0.14508943259716034
# epoch = 4, training loss = 0.149423748254776, validation loss = 0.16749007999897003
# epoch = 5, training loss = 0.10077730566263199, validation loss = 0.11245528608560562
# epoch = 6, training loss = 0.10482355952262878, validation loss = 0.11568420380353928
# epoch = 7, training loss = 0.0975058451294899, validation loss = 0.10616368800401688
# epoch = 8, training loss = 0.268684983253479, validation loss = 0.2727769911289215
# epoch = 9, training loss = 0.12198790907859802, validation loss = 0.12821552157402039
# epoch = 10, training loss = 0.7636616826057434, validation loss = 0.7884510159492493
# epoch = 11, training loss = 0.08440191298723221, validation loss = 0.0929284319281578
# epoch = 12, training loss = 0.34602904319763184, validation loss = 0.34702759981155396
# EarlyStopping counter: 1 out of 10
# epoch = 13, training loss = 0.4275956451892853, validation loss = 0.4458589255809784
# EarlyStopping counter: 2 out of 10
# epoch = 14, training loss = 0.20973341166973114, validation loss = 0.22670778632164001
# EarlyStopping counter: 3 out of 10
# epoch = 15, training loss = 0.28094419836997986, validation loss = 0.28460291028022766
# EarlyStopping counter: 4 out of 10
# epoch = 16, training loss = 0.14207355678081512, validation loss = 0.14636094868183136
# EarlyStopping counter: 5 out of 10
# epoch = 17, training loss = 0.08510149270296097, validation loss = 0.09420501440763474
# EarlyStopping counter: 6 out of 10
# epoch = 18, training loss = 0.08986760675907135, validation loss = 0.09702549874782562
# EarlyStopping counter: 7 out of 10
# epoch = 19, training loss = 0.08920153975486755, validation loss = 0.09616564214229584
# EarlyStopping counter: 8 out of 10
# epoch = 20, training loss = 0.07891657203435898, validation loss = 0.09035855531692505
# epoch = 21, training loss = 0.31437936425209045, validation loss = 0.3153453469276428
# EarlyStopping counter: 1 out of 10
# epoch = 22, training loss = 0.12374874204397202, validation loss = 0.1290614753961563
# EarlyStopping counter: 2 out of 10
# epoch = 23, training loss = 0.09159118682146072, validation loss = 0.10236546397209167
# EarlyStopping counter: 3 out of 10
# epoch = 24, training loss = 0.19320279359817505, validation loss = 0.20754966139793396
# EarlyStopping counter: 4 out of 10
# epoch = 25, training loss = 0.07651282101869583, validation loss = 0.08533965796232224
# epoch = 26, training loss = 0.07839889824390411, validation loss = 0.08894582837820053
# EarlyStopping counter: 1 out of 10
# epoch = 27, training loss = 0.14645637571811676, validation loss = 0.16113273799419403
# EarlyStopping counter: 2 out of 10
# epoch = 28, training loss = 0.10946927219629288, validation loss = 0.12250381708145142
# EarlyStopping counter: 3 out of 10
# epoch = 29, training loss = 0.11333025246858597, validation loss = 0.12502074241638184
# EarlyStopping counter: 4 out of 10
# epoch = 30, training loss = 0.18260227143764496, validation loss = 0.18535728752613068
# EarlyStopping counter: 5 out of 10
# epoch = 31, training loss = 1.0050013065338135, validation loss = 1.0329488515853882
# EarlyStopping counter: 6 out of 10
# epoch = 32, training loss = 0.07851534336805344, validation loss = 0.08624596148729324
# EarlyStopping counter: 7 out of 10
# epoch = 33, training loss = 0.08773767948150635, validation loss = 0.09877442568540573
# EarlyStopping counter: 8 out of 10
# epoch = 34, training loss = 0.14782769978046417, validation loss = 0.15975125133991241
# EarlyStopping counter: 9 out of 10
# epoch = 35, training loss = 0.24338293075561523, validation loss = 0.25742295384407043
# EarlyStopping counter: 10 out of 10
# Early stopping
